# %% [markdown]
# ---
# title: "Ai Job Market & Salary Analysis"
# format:
#   html:
#     code-fold: false
#     code-overflow: wrap
#     code-tools: false
#     echo: false
#     warning: false
#     message: false
# ---

# %% [markdown]
# ## Introduction
